# %%
from langchain_text_splitters import CharacterTextSplitter

# %%
text = """Artificial intelligence is transforming technology and shaping the future. 
Machine learning algorithms are becoming more sophisticated every day.
Deep learning models can now process vast amounts of data efficiently.

Natural language processing has made significant strides in recent years.
Computer vision systems can now identify objects with remarkable accuracy.
Reinforcement learning is enabling robots to learn complex tasks autonomously.

The impact of AI extends across multiple industries including healthcare, finance, and transportation.
Ethical considerations around AI development are becoming increasingly important.
Researchers are working on making AI systems more transparent and explainable."""

# %%
splitter = CharacterTextSplitter(
    chunk_size = 100,
    chunk_overlap = 0,
    length_function = len,
    separator = ''
)

# %%
chunks = splitter.split_text(text=text)

# %%
print(chunks)
print(len(chunks))
# Out:
# ['Artificial intelligence is transforming technology and shaping the future. \nMachine learning algorit', 'hms are becoming more sophisticated every day.\nDeep learning models can now process vast amounts of', 'data efficiently.\n\nNatural language processing has made significant strides in recent years.\nCompute', 'r vision systems can now identify objects with remarkable accuracy.\nReinforcement learning is enabli', 'ng robots to learn complex tasks autonomously.\n\nThe impact of AI extends across multiple industries', 'including healthcare, finance, and transportation.\nEthical considerations around AI development are', 'becoming increasingly important.\nResearchers are working on making AI systems more transparent and e', 'xplainable.']
# 8

# %%
from termcolor import COLORS, colored
from random import choice

# %%
print(COLORS)
# Out:
# {'black': 30, 'grey': 30, 'red': 31, 'green': 32, 'yellow': 33, 'blue': 34, 'magenta': 35, 'cyan': 36, 'light_grey': 37, 'dark_grey': 90, 'light_red': 91, 'light_green': 92, 'light_yellow': 93, 'light_blue': 94, 'light_magenta': 95, 'light_cyan': 96, 'white': 97}

# %%
colors_list = list(COLORS.keys())[2:8]
colors_list
# Out:
# ['red', 'green', 'yellow', 'blue', 'magenta', 'cyan']

# %%
def display_chunks(chunks):
    colors_list = list(COLORS.keys())[2:8]
    print(f'Total number of chunks: {len(chunks)}')
    for num, chunk in enumerate(chunks, 1):
        print(f'Chunk {num}: Length {len(chunk)} chars')
        print(colored(text=chunk, color=choice(colors_list)), end='\n\n')

# %%
display_chunks(chunks=chunks)
# Out:
# Total number of chunks: 8
# Chunk 1: Length 100 chars
# Artificial intelligence is transforming technology and shaping the future.
# Machine learning algorit
#
# Chunk 2: Length 99 chars
# hms are becoming more sophisticated every day.
# Deep learning models can now process vast amounts of
#
# Chunk 3: Length 100 chars
# data efficiently.
#
# Natural language processing has made significant strides in recent years.
# Compute
#
# Chunk 4: Length 100 chars
# r vision systems can now identify objects with remarkable accuracy.
# Reinforcement learning is enabli
#
# Chunk 5: Length 99 chars
# ng robots to learn complex tasks autonomously.
#
# The impact of AI extends across multiple industries
#
# Chunk 6: Length 99 chars
# including healthcare, finance, and transportation.
# Ethical considerations around AI development are
#
# Chunk 7: Length 100 chars
# becoming increasingly important.
# Researchers are working on making AI systems more transparent and e
#
# Chunk 8: Length 11 chars
# xplainable.

# %%
def create_chunks(text: str, chunk_size: int,
                  separator: str, chunk_overlap: int = 0) -> list[str]:
    splitter = CharacterTextSplitter(
        chunk_size=chunk_size,
        chunk_overlap=chunk_overlap,
        separator=separator
    )
    
    chunks = splitter.split_text(text=text)
    return chunks

# %%
display_chunks(create_chunks(text=text, chunk_size=300, separator=""))
# Out:
# Total number of chunks: 3
# Chunk 1: Length 300 chars
# Artificial intelligence is transforming technology and shaping the future.
# Machine learning algorithms are becoming more sophisticated every day.
# Deep learning models can now process vast amounts of data efficiently.
#
# Natural language processing has made significant strides in recent years.
# Compute
#
# Chunk 2: Length 299 chars
# r vision systems can now identify objects with remarkable accuracy.
# Reinforcement learning is enabling robots to learn complex tasks autonomously.
#
# The impact of AI extends across multiple industries including healthcare, finance, and transportation.
# Ethical considerations around AI development are
#
# Chunk 3: Length 111 chars
# becoming increasingly important.
# Researchers are working on making AI systems more transparent and explainable.

# %%
## word boundaries

display_chunks(create_chunks(text, 100, " "))
# Out:
# Total number of chunks: 8
# Chunk 1: Length 92 chars
# Artificial intelligence is transforming technology and shaping the future.
# Machine learning
#
# Chunk 2: Length 95 chars
# algorithms are becoming more sophisticated every day.
# Deep learning models can now process vast
#
# Chunk 3: Length 96 chars
# amounts of data efficiently.
#
# Natural language processing has made significant strides in recent
#
# Chunk 4: Length 95 chars
# years.
# Computer vision systems can now identify objects with remarkable accuracy.
# Reinforcement
#
# Chunk 5: Length 97 chars
# learning is enabling robots to learn complex tasks autonomously.
#
# The impact of AI extends across
#
# Chunk 6: Length 100 chars
# multiple industries including healthcare, finance, and transportation.
# Ethical considerations around
#
# Chunk 7: Length 96 chars
# AI development are becoming increasingly important.
# Researchers are working on making AI systems
#
# Chunk 8: Length 33 chars
# more transparent and explainable.

# %%
# based on paragraphs

display_chunks(create_chunks(text, 250, "\n\n"))
# Out:
# Total number of chunks: 3
# Chunk 1: Length 217 chars
# Artificial intelligence is transforming technology and shaping the future.
# Machine learning algorithms are becoming more sophisticated every day.
# Deep learning models can now process vast amounts of data efficiently.
#
# Chunk 2: Length 227 chars
# Natural language processing has made significant strides in recent years.
# Computer vision systems can now identify objects with remarkable accuracy.
# Reinforcement learning is enabling robots to learn complex tasks autonomously.
#
# Chunk 3: Length 263 chars
# The impact of AI extends across multiple industries including healthcare, finance, and transportation.
# Ethical considerations around AI development are becoming increasingly important.
# Researchers are working on making AI systems more transparent and explainable.

# %%
splitter = CharacterTextSplitter(
    chunk_size=100,
    chunk_overlap=10,
    separator=''
)
chunks = splitter.split_text(text=text)
display_chunks(chunks)
# Out:
# Total number of chunks: 8
# Chunk 1: Length 100 chars
# Artificial intelligence is transforming technology and shaping the future.
# Machine learning algorit
#
# Chunk 2: Length 100 chars
# ng algorithms are becoming more sophisticated every day.
# Deep learning models can now process vast a
#
# Chunk 3: Length 100 chars
# ess vast amounts of data efficiently.
#
# Natural language processing has made significant strides in r
#
# Chunk 4: Length 100 chars
# rides in recent years.
# Computer vision systems can now identify objects with remarkable accuracy.
# Re
#
# Chunk 5: Length 100 chars
# curacy.
# Reinforcement learning is enabling robots to learn complex tasks autonomously.
#
# The impact o
#
# Chunk 6: Length 100 chars
# e impact of AI extends across multiple industries including healthcare, finance, and transportation.
#
# Chunk 7: Length 100 chars
# portation.
# Ethical considerations around AI development are becoming increasingly important.
# Researc
#
# Chunk 8: Length 81 chars
# t.
# Researchers are working on making AI systems more transparent and explainable.

# %% [markdown]
# ### Token based chunking

# %%
token_splitter = CharacterTextSplitter.from_tiktoken_encoder(
    encoding_name='cl100k_base',
    chunk_size=50,
    chunk_overlap=5
)

# %%
token_splitter.split_text(text)
# Out:
# ['Artificial intelligence is transforming technology and shaping the future. \nMachine learning algorithms are becoming more sophisticated every day.\nDeep learning models can now process vast amounts of data efficiently.',
#  'Natural language processing has made significant strides in recent years.\nComputer vision systems can now identify objects with remarkable accuracy.\nReinforcement learning is enabling robots to learn complex tasks autonomously.',
#  'The impact of AI extends across multiple industries including healthcare, finance, and transportation.\nEthical considerations around AI development are becoming increasingly important.\nResearchers are working on making AI systems more transparent and explainable.']

# %% [markdown]
# ### Splitting documents

# %%
from langchain_core.documents import Document

# %%
docs = [Document(
    page_content=text,
    metadata={'source':'Text on AI'}
)]

print(docs)
# Out:
# [Document(metadata={'source': 'Text on AI'}, page_content='Artificial intelligence is transforming technology and shaping the future. \nMachine learning algorithms are becoming more sophisticated every day.\nDeep learning models can now process vast amounts of data efficiently.\n\nNatural language processing has made significant strides in recent years.\nComputer vision systems can now identify objects with remarkable accuracy.\nReinforcement learning is enabling robots to learn complex tasks autonomously.\n\nThe impact of AI extends across multiple industries including healthcare, finance, and transportation.\nEthical considerations around AI development are becoming increasingly important.\nResearchers are working on making AI systems more transparent and explainable.')]

# %%
# create splitter

splitter = CharacterTextSplitter(
    chunk_size = 100,
    chunk_overlap = 20,
    separator=""
)

# %%
## split_documents

chunks = splitter.split_documents(docs)

# %%
len(chunks)
print(chunks)
# Out:
# [Document(metadata={'source': 'Text on AI'}, page_content='Artificial intelligence is transforming technology and shaping the future. \nMachine learning algorit'), Document(metadata={'source': 'Text on AI'}, page_content='ine learning algorithms are becoming more sophisticated every day.\nDeep learning models can now proc'), Document(metadata={'source': 'Text on AI'}, page_content='models can now process vast amounts of data efficiently.\n\nNatural language processing has made sign'), Document(metadata={'source': 'Text on AI'}, page_content='essing has made significant strides in recent years.\nComputer vision systems can now identify object'), Document(metadata={'source': 'Text on AI'}, page_content='now identify objects with remarkable accuracy.\nReinforcement learning is enabling robots to learn c'), Document(metadata={'source': 'Text on AI'}, page_content='ng robots to learn complex tasks autonomously.\n\nThe impact of AI extends across multiple industries'), Document(metadata={'source': 'Text on AI'}, page_content='multiple industries including healthcare, finance, and transportation.\nEthical considerations around'), Document(metadata={'source': 'Text on AI'}, page_content='onsiderations around AI development are becoming increasingly important.\nResearchers are working on'), Document(metadata={'source': 'Text on AI'}, page_content='hers are working on making AI systems more transparent and explainable.')]

# %%
chunks[0]
# Out:
# Document(metadata={'source': 'Text on AI'}, page_content='Artificial intelligence is transforming technology and shaping the future. \nMachine learning algorit')
